# %%
# Setup: import libraries
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

sns.set_theme(style='whitegrid')
# Improve numeric readability globally
from matplotlib.ticker import FuncFormatter

# Currency formatter for PHP with K/M/B suffixes
def php_fmt(x, pos=None):
    try:
        x = float(x)
    except Exception:
        return ''
    ax = abs(x)
    if ax >= 1_000_000_000:
        val = f"{x/1_000_000_000:.1f}B"
    elif ax >= 1_000_000:
        val = f"{x/1_000_000:.1f}M"
    elif ax >= 1_000:
        val = f"{x/1_000:.1f}K"
    else:
        val = f"{x:.0f}"
    return f"₱{val}"

# Pandas display: thousands separators with two decimals
pd.options.display.float_format = lambda v: f"{v:,.2f}"

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv('dpwh_flood_control_projects.csv')
df
# Out:
#      MainIsland                            Region           Province  \
# 0         Luzon  Cordillera Administrative Region             Apayao
# 1         Luzon  Cordillera Administrative Region             Apayao
# 2         Luzon  Cordillera Administrative Region             Apayao
# 3         Luzon  Cordillera Administrative Region             Apayao
# 4         Luzon  Cordillera Administrative Region             Apayao
# ...         ...                               ...                ...
# 9850   Mindanao                       Region XIII  Surigao del Norte
# 9851   Mindanao                       Region XIII  Surigao del Norte
# 9852   Mindanao                       Region XIII  Surigao del Norte
# 9853   Mindanao                       Region XIII  Surigao del Norte
# 9854   Mindanao                       Region XIII  Surigao del Norte
#
#                                  LegislativeDistrict  \
# 0                      APAYAO (LEGISLATIVE DISTRICT)
# 1                      APAYAO (LEGISLATIVE DISTRICT)
# 2                      APAYAO (LEGISLATIVE DISTRICT)
# 3                      APAYAO (LEGISLATIVE DISTRICT)
# 4                      APAYAO (LEGISLATIVE DISTRICT)
# ...                                              ...
# 9850  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9851  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9852  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9853  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9854  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
#
#                         Municipality  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 9850      BURGOS (SURIGAO DEL NORTE)
# 9851  SAN BENITO (SURIGAO DEL NORTE)
# 9852  SAN BENITO (SURIGAO DEL NORTE)
# 9853     SOCORRO (SURIGAO DEL NORTE)
# 9854       PILAR (SURIGAO DEL NORTE)
#
#                               DistrictEngineeringOffice    ProjectId  \
# 0                Apayao 2nd District Engineering Office  P00526268LZ
# 1                Apayao 2nd District Engineering Office  P00526368LZ
# 2                Apayao 2nd District Engineering Office  P00526369LZ
# 3                Apayao 2nd District Engineering Office  P00561270LZ
# 4                Apayao 2nd District Engineering Office  P00561652LZ
# ...                                                 ...          ...
# 9850  Surigao del Norte 1st District Engineering Office  P00836163MN
# 9851  Surigao del Norte 1st District Engineering Office  P00721401MN
# 9852  Surigao del Norte 1st District Engineering Office  P00836198MN
# 9853  Surigao del Norte 1st District Engineering Office  P00734420MN
# 9854  Surigao del Norte 1st District Engineering Office  P00745952MN
#
#                                             ProjectName  \
# 0     Construction of Poblacion Flood Control Struct...
# 1     Construction of Cabicungan Flood Control Struc...
# 2     Construction of Sipa-San Mariano Flood Control...
# 3     Construction of Sta. Filomena Floodway/ Flood ...
# 4     Construction of Sinigpit Flood Control, Calana...
# ...                                                 ...
# 9850  Construction of Shore Protection Structure alo...
# 9851  Construction of Flood Control Structure, Nuevo...
# 9852  Construction of Slope Protection Structure alo...
# 9853  Construction of Shore Protection,Brgy. Pamosai...
# 9854  Reconstruction/Rehabilitation of Seawall and R...
#
#                                              TypeOfWork  FundingYear  ...  \
# 0            Construction of Flood Mitigation Structure         2021  ...
# 1            Construction of Flood Mitigation Structure         2021  ...
# 2            Construction of Flood Mitigation Structure         2021  ...
# 3            Construction of Flood Mitigation Structure         2021  ...
# 4            Construction of Flood Mitigation Structure         2021  ...
# ...                                                 ...          ...  ...
# 9850         Construction of Flood Mitigation Structure         2024  ...
# 9851         Construction of Flood Mitigation Structure         2023  ...
# 9852         Construction of Slope Protection Structure         2024  ...
# 9853         Construction of Flood Mitigation Structure         2023  ...
# 9854  Rehabilitation / Major Repair of Flood Control...         2023  ...
#
#      ContractCost ActualCompletionDate  \
# 0      92692943.8           2022-10-03
# 1      47521251.3           2022-11-24
# 2     45942583.67           2022-11-28
# 3         9900000           2022-12-15
# 4         4950000           2022-09-23
# ...           ...                  ...
# 9850  98999966.68           2024-12-22
# 9851  29395023.19           2023-11-16
# 9852  39499723.17           2025-01-17
# 9853   49399902.5           2024-04-14
# 9854  92206234.28           2024-05-19
#
#                                              Contractor ContractorCount  \
# 0                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 1                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 2                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 3                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 4      ALEPHNORTH PEAK CONSTRUCTION AND DEVELOPMENT CO.               1
# ...                                                 ...             ...
# 9850  RCDG CONSTRUCTION CORPORATION / LPO1 GROUP OF ...               2
# 9851                            DQT BUILDERS AND SUPPLY               1
# 9852                        BOOMETRIX DEVELOPMENT CORP.               1
# 9853           ROAD EDGE TRADING & DEVELOPMENT SERVICES               1
# 9854  DQT BUILDERS AND SUPPLY / ARN BUILDERS, INC. (...               2
#
#        StartDate  ProjectLatitude ProjectLongitude  ProvincialCapital  \
# 0     2021-03-18            18.25           121.05            Kabugao
# 1     2021-12-01            18.51           121.08            Kabugao
# 2     2021-12-01            18.27           121.42            Kabugao
# 3     2021-12-01            18.54           121.08            Kabugao
# 4     2021-12-01            18.53           121.10            Kabugao
# ...          ...              ...              ...                ...
# 9850  2024-05-13            10.02           126.07       Surigao City
# 9851  2023-05-03             9.94           126.04       Surigao City
# 9852  2024-04-05             9.97           126.01       Surigao City
# 9853  2023-07-13             9.65           125.92       Surigao City
# 9854  2023-11-28             9.65           125.91       Surigao City
#
#       ProvincialCapitalLatitude ProvincialCapitalLongitude
# 0                         18.02                     121.17
# 1                         18.02                     121.17
# 2                         18.02                     121.17
# 3                         18.02                     121.17
# 4                         18.02                     121.17
# ...                         ...                        ...
# 9850                       9.78                     125.49
# 9851                       9.78                     125.49
# 9852                       9.78                     125.49
# 9853                       9.78                     125.49
# 9854                       9.78                     125.49
#
# [9855 rows x 22 columns]

# %% [markdown]
# # Data Cleaning

# %%
# Inspect data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9855 entries, 0 to 9854
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   MainIsland                  9855 non-null   object
#  1   Region                      9855 non-null   object
#  2   Province                    9855 non-null   object
#  3   LegislativeDistrict         9855 non-null   object
#  4   Municipality                9189 non-null   object
#  5   DistrictEngineeringOffice   9855 non-null   object
#  6   ProjectId                   9855 non-null   object
#  7   ProjectName                 9855 non-null   object
#  8   TypeOfWork                  9855 non-null   object
#  9   FundingYear                 9855 non-null   int64
#  10  ContractId                  9855 non-null   object
#  11  ApprovedBudgetForContract   9855 non-null   object
#  12  ContractCost                9855 non-null   object
#  13  ActualCompletionDate        9855 non-null   object
#  14  Contractor                  9855 non-null   object
#  15  ContractorCount             9855 non-null   int64
#  16  StartDate                   9855 non-null   object
#  17  ProjectLatitude             9855 non-null   float64
#  18  ProjectLongitude            9855 non-null   float64
#  19  ProvincialCapital           9855 non-null   object
#  20  ProvincialCapitalLatitude   9855 non-null   float64
#  21  ProvincialCapitalLongitude  9855 non-null   float64
# dtypes: float64(4), int64(2), object(16)
# memory usage: 1.7+ MB

# %%
# Count distinct values per column
df.nunique()
# Out:
# MainIsland                       3
# Region                          16
# Province                        84
# LegislativeDistrict            252
# Municipality                  1197
# DistrictEngineeringOffice      199
# ProjectId                     9827
# ProjectName                   9712
# TypeOfWork                      18
# FundingYear                      8
# ContractId                    9698
# ApprovedBudgetForContract     4916
# ContractCost                  8025
# ActualCompletionDate          1028
# Contractor                    2409
# ContractorCount                  3
# StartDate                      738
# ProjectLatitude               9500
# ProjectLongitude              9471
# ProvincialCapital               84
# ProvincialCapitalLatitude       84
# ProvincialCapitalLongitude      85
# dtype: int64

# %%
# No duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# List all column names
df.columns
# Out:
# Index(['MainIsland', 'Region', 'Province', 'LegislativeDistrict',
#        'Municipality', 'DistrictEngineeringOffice', 'ProjectId', 'ProjectName',
#        'TypeOfWork', 'FundingYear', 'ContractId', 'ApprovedBudgetForContract',
#        'ContractCost', 'ActualCompletionDate', 'Contractor', 'ContractorCount',
#        'StartDate', 'ProjectLatitude', 'ProjectLongitude', 'ProvincialCapital',
#        'ProvincialCapitalLatitude', 'ProvincialCapitalLongitude'],
#       dtype='object')

# %%
# Null count per column
df.isnull().sum()
# Out:
# MainIsland                      0
# Region                          0
# Province                        0
# LegislativeDistrict             0
# Municipality                  666
# DistrictEngineeringOffice       0
# ProjectId                       0
# ProjectName                     0
# TypeOfWork                      0
# FundingYear                     0
# ContractId                      0
# ApprovedBudgetForContract       0
# ContractCost                    0
# ActualCompletionDate            0
# Contractor                      0
# ContractorCount                 0
# StartDate                       0
# ProjectLatitude                 0
# ProjectLongitude                0
# ProvincialCapital               0
# ProvincialCapitalLatitude       0
# ProvincialCapitalLongitude      0
# dtype: int64

# %%
# Converted ApprovedBudgetForContract and ContractCost column to numeric
df['ApprovedBudgetForContract'] = pd.to_numeric(df['ApprovedBudgetForContract'],errors='coerce')
df['ContractCost'] = pd.to_numeric(df['ContractCost'],errors='coerce')
df['FundingYear'] = pd.to_numeric(df['FundingYear'],errors='coerce')
df
# Out:
#      MainIsland                            Region           Province  \
# 0         Luzon  Cordillera Administrative Region             Apayao
# 1         Luzon  Cordillera Administrative Region             Apayao
# 2         Luzon  Cordillera Administrative Region             Apayao
# 3         Luzon  Cordillera Administrative Region             Apayao
# 4         Luzon  Cordillera Administrative Region             Apayao
# ...         ...                               ...                ...
# 9850   Mindanao                       Region XIII  Surigao del Norte
# 9851   Mindanao                       Region XIII  Surigao del Norte
# 9852   Mindanao                       Region XIII  Surigao del Norte
# 9853   Mindanao                       Region XIII  Surigao del Norte
# 9854   Mindanao                       Region XIII  Surigao del Norte
#
#                                  LegislativeDistrict  \
# 0                      APAYAO (LEGISLATIVE DISTRICT)
# 1                      APAYAO (LEGISLATIVE DISTRICT)
# 2                      APAYAO (LEGISLATIVE DISTRICT)
# 3                      APAYAO (LEGISLATIVE DISTRICT)
# 4                      APAYAO (LEGISLATIVE DISTRICT)
# ...                                              ...
# 9850  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9851  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9852  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9853  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9854  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
#
#                         Municipality  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 9850      BURGOS (SURIGAO DEL NORTE)
# 9851  SAN BENITO (SURIGAO DEL NORTE)
# 9852  SAN BENITO (SURIGAO DEL NORTE)
# 9853     SOCORRO (SURIGAO DEL NORTE)
# 9854       PILAR (SURIGAO DEL NORTE)
#
#                               DistrictEngineeringOffice    ProjectId  \
# 0                Apayao 2nd District Engineering Office  P00526268LZ
# 1                Apayao 2nd District Engineering Office  P00526368LZ
# 2                Apayao 2nd District Engineering Office  P00526369LZ
# 3                Apayao 2nd District Engineering Office  P00561270LZ
# 4                Apayao 2nd District Engineering Office  P00561652LZ
# ...                                                 ...          ...
# 9850  Surigao del Norte 1st District Engineering Office  P00836163MN
# 9851  Surigao del Norte 1st District Engineering Office  P00721401MN
# 9852  Surigao del Norte 1st District Engineering Office  P00836198MN
# 9853  Surigao del Norte 1st District Engineering Office  P00734420MN
# 9854  Surigao del Norte 1st District Engineering Office  P00745952MN
#
#                                             ProjectName  \
# 0     Construction of Poblacion Flood Control Struct...
# 1     Construction of Cabicungan Flood Control Struc...
# 2     Construction of Sipa-San Mariano Flood Control...
# 3     Construction of Sta. Filomena Floodway/ Flood ...
# 4     Construction of Sinigpit Flood Control, Calana...
# ...                                                 ...
# 9850  Construction of Shore Protection Structure alo...
# 9851  Construction of Flood Control Structure, Nuevo...
# 9852  Construction of Slope Protection Structure alo...
# 9853  Construction of Shore Protection,Brgy. Pamosai...
# 9854  Reconstruction/Rehabilitation of Seawall and R...
#
#                                              TypeOfWork  FundingYear  ...  \
# 0            Construction of Flood Mitigation Structure         2021  ...
# 1            Construction of Flood Mitigation Structure         2021  ...
# 2            Construction of Flood Mitigation Structure         2021  ...
# 3            Construction of Flood Mitigation Structure         2021  ...
# 4            Construction of Flood Mitigation Structure         2021  ...
# ...                                                 ...          ...  ...
# 9850         Construction of Flood Mitigation Structure         2024  ...
# 9851         Construction of Flood Mitigation Structure         2023  ...
# 9852         Construction of Slope Protection Structure         2024  ...
# 9853         Construction of Flood Mitigation Structure         2023  ...
# 9854  Rehabilitation / Major Repair of Flood Control...         2023  ...
#
#       ContractCost  ActualCompletionDate  \
# 0    92,692,943.80            2022-10-03
# 1    47,521,251.30            2022-11-24
# 2    45,942,583.67            2022-11-28
# 3     9,900,000.00            2022-12-15
# 4     4,950,000.00            2022-09-23
# ...            ...                   ...
# 9850 98,999,966.68            2024-12-22
# 9851 29,395,023.19            2023-11-16
# 9852 39,499,723.17            2025-01-17
# 9853 49,399,902.50            2024-04-14
# 9854 92,206,234.28            2024-05-19
#
#                                              Contractor ContractorCount  \
# 0                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 1                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 2                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 3                  ASC CONSTRUCTION & CONCRETE PRODUCTS               1
# 4      ALEPHNORTH PEAK CONSTRUCTION AND DEVELOPMENT CO.               1
# ...                                                 ...             ...
# 9850  RCDG CONSTRUCTION CORPORATION / LPO1 GROUP OF ...               2
# 9851                            DQT BUILDERS AND SUPPLY               1
# 9852                        BOOMETRIX DEVELOPMENT CORP.               1
# 9853           ROAD EDGE TRADING & DEVELOPMENT SERVICES               1
# 9854  DQT BUILDERS AND SUPPLY / ARN BUILDERS, INC. (...               2
#
#        StartDate  ProjectLatitude ProjectLongitude  ProvincialCapital  \
# 0     2021-03-18            18.25           121.05            Kabugao
# 1     2021-12-01            18.51           121.08            Kabugao
# 2     2021-12-01            18.27           121.42            Kabugao
# 3     2021-12-01            18.54           121.08            Kabugao
# 4     2021-12-01            18.53           121.10            Kabugao
# ...          ...              ...              ...                ...
# 9850  2024-05-13            10.02           126.07       Surigao City
# 9851  2023-05-03             9.94           126.04       Surigao City
# 9852  2024-04-05             9.97           126.01       Surigao City
# 9853  2023-07-13             9.65           125.92       Surigao City
# 9854  2023-11-28             9.65           125.91       Surigao City
#
#       ProvincialCapitalLatitude ProvincialCapitalLongitude
# 0                         18.02                     121.17
# 1                         18.02                     121.17
# 2                         18.02                     121.17
# 3                         18.02                     121.17
# 4                         18.02                     121.17
# ...                         ...                        ...
# 9850                       9.78                     125.49
# 9851                       9.78                     125.49
# 9852                       9.78                     125.49
# 9853                       9.78                     125.49
# 9854                       9.78                     125.49
#
# [9855 rows x 22 columns]

# %%
# Convert dates; engineer duration (days) and contractor project counts
df['StartDate'] = pd.to_datetime(df['StartDate'], errors='coerce')
df['ActualCompletionDate'] = pd.to_datetime(df['ActualCompletionDate'], errors='coerce')
# Duration in days between start and actual completion
df['DurationDays'] = (df['ActualCompletionDate'] - df['StartDate']).dt.days
# Number of projects per contractor (attached per row)
df['ContractorCount'] = df.groupby('Contractor')['ProjectId'].transform('count')
df
# Out:
#      MainIsland                            Region           Province  \
# 0         Luzon  Cordillera Administrative Region             Apayao
# 1         Luzon  Cordillera Administrative Region             Apayao
# 2         Luzon  Cordillera Administrative Region             Apayao
# 3         Luzon  Cordillera Administrative Region             Apayao
# 4         Luzon  Cordillera Administrative Region             Apayao
# ...         ...                               ...                ...
# 9850   Mindanao                       Region XIII  Surigao del Norte
# 9851   Mindanao                       Region XIII  Surigao del Norte
# 9852   Mindanao                       Region XIII  Surigao del Norte
# 9853   Mindanao                       Region XIII  Surigao del Norte
# 9854   Mindanao                       Region XIII  Surigao del Norte
#
#                                  LegislativeDistrict  \
# 0                      APAYAO (LEGISLATIVE DISTRICT)
# 1                      APAYAO (LEGISLATIVE DISTRICT)
# 2                      APAYAO (LEGISLATIVE DISTRICT)
# 3                      APAYAO (LEGISLATIVE DISTRICT)
# 4                      APAYAO (LEGISLATIVE DISTRICT)
# ...                                              ...
# 9850  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9851  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9852  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9853  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9854  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
#
#                         Municipality  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 9850      BURGOS (SURIGAO DEL NORTE)
# 9851  SAN BENITO (SURIGAO DEL NORTE)
# 9852  SAN BENITO (SURIGAO DEL NORTE)
# 9853     SOCORRO (SURIGAO DEL NORTE)
# 9854       PILAR (SURIGAO DEL NORTE)
#
#                               DistrictEngineeringOffice    ProjectId  \
# 0                Apayao 2nd District Engineering Office  P00526268LZ
# 1                Apayao 2nd District Engineering Office  P00526368LZ
# 2                Apayao 2nd District Engineering Office  P00526369LZ
# 3                Apayao 2nd District Engineering Office  P00561270LZ
# 4                Apayao 2nd District Engineering Office  P00561652LZ
# ...                                                 ...          ...
# 9850  Surigao del Norte 1st District Engineering Office  P00836163MN
# 9851  Surigao del Norte 1st District Engineering Office  P00721401MN
# 9852  Surigao del Norte 1st District Engineering Office  P00836198MN
# 9853  Surigao del Norte 1st District Engineering Office  P00734420MN
# 9854  Surigao del Norte 1st District Engineering Office  P00745952MN
#
#                                             ProjectName  \
# 0     Construction of Poblacion Flood Control Struct...
# 1     Construction of Cabicungan Flood Control Struc...
# 2     Construction of Sipa-San Mariano Flood Control...
# 3     Construction of Sta. Filomena Floodway/ Flood ...
# 4     Construction of Sinigpit Flood Control, Calana...
# ...                                                 ...
# 9850  Construction of Shore Protection Structure alo...
# 9851  Construction of Flood Control Structure, Nuevo...
# 9852  Construction of Slope Protection Structure alo...
# 9853  Construction of Shore Protection,Brgy. Pamosai...
# 9854  Reconstruction/Rehabilitation of Seawall and R...
#
#                                              TypeOfWork  FundingYear  ...  \
# 0            Construction of Flood Mitigation Structure         2021  ...
# 1            Construction of Flood Mitigation Structure         2021  ...
# 2            Construction of Flood Mitigation Structure         2021  ...
# 3            Construction of Flood Mitigation Structure         2021  ...
# 4            Construction of Flood Mitigation Structure         2021  ...
# ...                                                 ...          ...  ...
# 9850         Construction of Flood Mitigation Structure         2024  ...
# 9851         Construction of Flood Mitigation Structure         2023  ...
# 9852         Construction of Slope Protection Structure         2024  ...
# 9853         Construction of Flood Mitigation Structure         2023  ...
# 9854  Rehabilitation / Major Repair of Flood Control...         2023  ...
#
#      ActualCompletionDate                                         Contractor  \
# 0              2022-10-03               ASC CONSTRUCTION & CONCRETE PRODUCTS
# 1              2022-11-24               ASC CONSTRUCTION & CONCRETE PRODUCTS
# 2              2022-11-28               ASC CONSTRUCTION & CONCRETE PRODUCTS
# 3              2022-12-15               ASC CONSTRUCTION & CONCRETE PRODUCTS
# 4              2022-09-23   ALEPHNORTH PEAK CONSTRUCTION AND DEVELOPMENT CO.
# ...                   ...                                                ...
# 9850           2024-12-22  RCDG CONSTRUCTION CORPORATION / LPO1 GROUP OF ...
# 9851           2023-11-16                            DQT BUILDERS AND SUPPLY
# 9852           2025-01-17                        BOOMETRIX DEVELOPMENT CORP.
# 9853           2024-04-14           ROAD EDGE TRADING & DEVELOPMENT SERVICES
# 9854           2024-05-19  DQT BUILDERS AND SUPPLY / ARN BUILDERS, INC. (...
#
#       ContractorCount  StartDate ProjectLatitude  ProjectLongitude  \
# 0                  20 2021-03-18           18.25            121.05
# 1                  20 2021-12-01           18.51            121.08
# 2                  20 2021-12-01           18.27            121.42
# 3                  20 2021-12-01           18.54            121.08
# 4                   1 2021-12-01           18.53            121.10
# ...               ...        ...             ...               ...
# 9850                2 2024-05-13           10.02            126.07
# 9851                1 2023-05-03            9.94            126.04
# 9852                8 2024-04-05            9.97            126.01
# 9853               50 2023-07-13            9.65            125.92
# 9854                1 2023-11-28            9.65            125.91
#
#      ProvincialCapital  ProvincialCapitalLatitude  ProvincialCapitalLongitude  \
# 0              Kabugao                      18.02                      121.17
# 1              Kabugao                      18.02                      121.17
# 2              Kabugao                      18.02                      121.17
# 3              Kabugao                      18.02                      121.17
# 4              Kabugao                      18.02                      121.17
# ...                ...                        ...                         ...
# 9850      Surigao City                       9.78                      125.49
# 9851      Surigao City                       9.78                      125.49
# 9852      Surigao City                       9.78                      125.49
# 9853      Surigao City                       9.78                      125.49
# 9854      Surigao City                       9.78                      125.49
#
#      DurationDays
# 0             564
# 1             358
# 2             362
# 3             379
# 4             296
# ...           ...
# 9850          223
# 9851          197
# 9852          287
# 9853          276
# 9854          173
#
# [9855 rows x 23 columns]

# %%
# Drop projects from 2018-2020 because of insufficient data
df = df.loc[~df['FundingYear'].isin([2018, 2019, 2020, 2021, 2025])].copy()
df['FundingYear'].value_counts()
df['StartDate'] = pd.to_datetime(df['StartDate'], errors='coerce').dt.strftime('%B-%d-%Y')
df
# Out:
#      MainIsland                            Region           Province  \
# 7         Luzon  Cordillera Administrative Region             Apayao
# 8         Luzon  Cordillera Administrative Region             Apayao
# 9         Luzon  Cordillera Administrative Region             Apayao
# 10        Luzon  Cordillera Administrative Region             Apayao
# 11        Luzon  Cordillera Administrative Region             Apayao
# ...         ...                               ...                ...
# 9850   Mindanao                       Region XIII  Surigao del Norte
# 9851   Mindanao                       Region XIII  Surigao del Norte
# 9852   Mindanao                       Region XIII  Surigao del Norte
# 9853   Mindanao                       Region XIII  Surigao del Norte
# 9854   Mindanao                       Region XIII  Surigao del Norte
#
#                                  LegislativeDistrict  \
# 7                      APAYAO (LEGISLATIVE DISTRICT)
# 8                      APAYAO (LEGISLATIVE DISTRICT)
# 9                      APAYAO (LEGISLATIVE DISTRICT)
# 10                     APAYAO (LEGISLATIVE DISTRICT)
# 11                     APAYAO (LEGISLATIVE DISTRICT)
# ...                                              ...
# 9850  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9851  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9852  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9853  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9854  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
#
#                         Municipality  \
# 7                    CONNER (APAYAO)
# 8                    CONNER (APAYAO)
# 9                    CONNER (APAYAO)
# 10                   CONNER (APAYAO)
# 11                   CONNER (APAYAO)
# ...                              ...
# 9850      BURGOS (SURIGAO DEL NORTE)
# 9851  SAN BENITO (SURIGAO DEL NORTE)
# 9852  SAN BENITO (SURIGAO DEL NORTE)
# 9853     SOCORRO (SURIGAO DEL NORTE)
# 9854       PILAR (SURIGAO DEL NORTE)
#
#                               DistrictEngineeringOffice    ProjectId  \
# 7                Apayao 1st District Engineering Office  P00620988LZ
# 8                Apayao 1st District Engineering Office  P00620472LZ
# 9                Apayao 1st District Engineering Office  P00620136LZ
# 10               Apayao 1st District Engineering Office  P00726398LZ
# 11               Apayao 1st District Engineering Office  P00726655LZ
# ...                                                 ...          ...
# 9850  Surigao del Norte 1st District Engineering Office  P00836163MN
# 9851  Surigao del Norte 1st District Engineering Office  P00721401MN
# 9852  Surigao del Norte 1st District Engineering Office  P00836198MN
# 9853  Surigao del Norte 1st District Engineering Office  P00734420MN
# 9854  Surigao del Norte 1st District Engineering Office  P00745952MN
#
#                                             ProjectName  \
# 7     Construction of Barren River (Upstream) Flood ...
# 8     Construction of Barren River (Upstream) Flood ...
# 9     Construction of Barren River (Downstream) Floo...
# 10    Construction of Barren River (Downstream) Floo...
# 11    Construction of Barren River (Downstream) Floo...
# ...                                                 ...
# 9850  Construction of Shore Protection Structure alo...
# 9851  Construction of Flood Control Structure, Nuevo...
# 9852  Construction of Slope Protection Structure alo...
# 9853  Construction of Shore Protection,Brgy. Pamosai...
# 9854  Reconstruction/Rehabilitation of Seawall and R...
#
#                                              TypeOfWork  FundingYear  ...  \
# 7            Construction of Flood Mitigation Structure         2022  ...
# 8            Construction of Flood Mitigation Structure         2022  ...
# 9            Construction of Flood Mitigation Structure         2022  ...
# 10                            Construction of Revetment         2023  ...
# 11                            Construction of Revetment         2023  ...
# ...                                                 ...          ...  ...
# 9850         Construction of Flood Mitigation Structure         2024  ...
# 9851         Construction of Flood Mitigation Structure         2023  ...
# 9852         Construction of Slope Protection Structure         2024  ...
# 9853         Construction of Flood Mitigation Structure         2023  ...
# 9854  Rehabilitation / Major Repair of Flood Control...         2023  ...
#
#                                              Contractor  ContractorCount  \
# 7                  PRIME MASTER CONST. AND DEV'T. CORP.                1
# 8                                BAHRAMLEY CONSTRUCTION                1
# 9                  ASC CONSTRUCTION & CONCRETE PRODUCTS               20
# 10                 ASC CONSTRUCTION & CONCRETE PRODUCTS               20
# 11                     GKA ENGINEERING AND CONSTRUCTION                1
# ...                                                 ...              ...
# 9850  RCDG CONSTRUCTION CORPORATION / LPO1 GROUP OF ...                2
# 9851                            DQT BUILDERS AND SUPPLY                1
# 9852                        BOOMETRIX DEVELOPMENT CORP.                8
# 9853           ROAD EDGE TRADING & DEVELOPMENT SERVICES               50
# 9854  DQT BUILDERS AND SUPPLY / ARN BUILDERS, INC. (...                1
#
#              StartDate ProjectLatitude ProjectLongitude  ProvincialCapital  \
# 7     February-09-2022           17.82           121.27            Kabugao
# 8        March-01-2022           17.82           121.27            Kabugao
# 9        April-04-2022           17.82           121.27            Kabugao
# 10    February-12-2023           17.82           121.27            Kabugao
# 11    February-12-2023           17.80           121.28            Kabugao
# ...                ...             ...              ...                ...
# 9850       May-13-2024           10.02           126.07       Surigao City
# 9851       May-03-2023            9.94           126.04       Surigao City
# 9852     April-05-2024            9.97           126.01       Surigao City
# 9853      July-13-2023            9.65           125.92       Surigao City
# 9854  November-28-2023            9.65           125.91       Surigao City
#
#      ProvincialCapitalLatitude  ProvincialCapitalLongitude  DurationDays  \
# 7                        18.02                      121.17           266
# 8                        18.02                      121.17           296
# 9                        18.02                      121.17           421
# 10                       18.02                      121.17           305
# 11                       18.02                      121.17           130
# ...                        ...                         ...           ...
# 9850                      9.78                      125.49           223
# 9851                      9.78                      125.49           197
# 9852                      9.78                      125.49           287
# 9853                      9.78                      125.49           276
# 9854                      9.78                      125.49           173
#
#      BudgetDifference
# 7          591,507.17
# 8           -1,075.32
# 9             -692.34
# 10               0.00
# 11               0.00
# ...               ...
# 9850            33.32
# 9851         4,976.81
# 9852       100,276.83
# 9853       100,097.50
# 9854       931,645.77
#
# [9043 rows x 24 columns]

# %%
# Drop rows with missing values in ApprovedBudgetForContract or ContractCost
df = df.dropna(subset=['ApprovedBudgetForContract','ContractCost'])

# %%
# Re-check dtypes and non-null counts after cleaning
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9043 entries, 7 to 9854
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   MainIsland                  9043 non-null   object
#  1   Region                      9043 non-null   object
#  2   Province                    9043 non-null   object
#  3   LegislativeDistrict         9043 non-null   object
#  4   Municipality                9042 non-null   object
#  5   DistrictEngineeringOffice   9043 non-null   object
#  6   ProjectId                   9043 non-null   object
#  7   ProjectName                 9043 non-null   object
#  8   TypeOfWork                  9043 non-null   object
#  9   FundingYear                 9043 non-null   int64
#  10  ContractId                  9043 non-null   object
#  11  ApprovedBudgetForContract   9043 non-null   float64
#  12  ContractCost                9043 non-null   float64
#  13  ActualCompletionDate        9043 non-null   datetime64[ns]
#  14  Contractor                  9043 non-null   object
#  15  ContractorCount             9043 non-null   int64
#  16  StartDate                   9043 non-null   datetime64[ns]
#  17  ProjectLatitude             9043 non-null   float64
#  18  ProjectLongitude            9043 non-null   float64
#  19  ProvincialCapital           9043 non-null   object
#  20  ProvincialCapitalLatitude   9043 non-null   float64
#  21  ProvincialCapitalLongitude  9043 non-null   float64
#  22  DurationDays                9043 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(3), object(12)
# memory usage: 1.7+ MB

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()[['ApprovedBudgetForContract', 'ContractCost']]
# Out:
#        ApprovedBudgetForContract   ContractCost
# count                   9,043.00       9,043.00
# mean               57,071,746.32  56,303,382.54
# min                 1,158,000.00   1,154,359.00
# 25%                28,949,999.64  27,380,790.05
# 50%                49,000,000.00  48,997,205.76
# 75%                86,850,000.00  86,844,690.24
# max               310,576,313.24 289,500,000.00
# std                40,018,427.41  39,652,211.09

# %%
# Number of Projects per Contractor from 2021-2025
contractor_count = df['Contractor'].value_counts()
contractor_count
# Out:
# Contractor
# LEGACY CONSTRUCTION CORPORATION (FORMERLY: LEGACY CONSTRUCTION)             102
# QM BUILDERS                                                                  87
# ALPHA & OMEGA GEN. CONTRACTOR & DEVELOPMENT CORP.                            82
# ST. TIMOTHY CONSTRUCTION CORPORATION                                         71
# SUNWEST, INC. (FORMERLY: SUNWEST CONSTRUCTION & DEVELOPMENT CORPORATION)     59
#                                                                            ...
# DAVE CONSTRUCTION / CM TAN CONSTRUCTION                                       1
# J.M. LACORTE CONSTRUCTION / LEXICON DEVELOPMENT CORPORATION                   1
# JQG BUILDERS                                                                  1
# BBC CONSTRUCTION / ADFIL CORPORATION                                          1
# ROCK DIWATA BUILDERS, INC. / FFJJ CONSTRUCTION                                1
# Name: count, Length: 2279, dtype: int64

# %%
# BudgetDifference = ApprovedBudgetForContract - ContractCost
df.loc[:, 'BudgetDifference'] = df['ApprovedBudgetForContract'] - df['ContractCost']
# Out:
# C:\Users\edlav\AppData\Local\Temp\ipykernel_139300\1500997602.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'BudgetDifference'] = df['ApprovedBudgetForContract'] - df['ContractCost']

# %%
# Group by FundingYear for yearly aggregations
year_grp = df.groupby('FundingYear')

# %%
# Yearly sums of ApprovedBudgetForContract and ContractCost
cost = year_grp[['ApprovedBudgetForContract','ContractCost']].sum()

# %%
# Total budget and cost for each year, their difference, and the percentage saved
df2 = pd.DataFrame({
    'TotalApprovedBudget': year_grp['ApprovedBudgetForContract'].sum(),
    'TotalContractCost': year_grp['ContractCost'].sum()
})
df2['Difference'] = df2['TotalApprovedBudget'] - df2['TotalContractCost']
df2['PercentageSaved'] = (df2['Difference'] / df2['TotalApprovedBudget']) * 100
df2
# Out:
#              TotalApprovedBudget  TotalContractCost       Difference  \
# FundingYear
# 2022          166,167,472,755.26 162,792,781,391.01 3,374,691,364.25
# 2023          204,607,156,165.90 201,877,335,583.62 2,729,820,582.28
# 2024          145,325,173,051.52 144,481,371,378.01   843,801,673.51
#
#              PercentageSaved
# FundingYear
# 2022                    2.03
# 2023                    1.33
# 2024                    0.58

# %%
# Project counts by District Engineering Office
df['DistrictEngineeringOffice'].value_counts()
# Out:
# DistrictEngineeringOffice
# Bulacan 1st District Engineering Office                445
# Metro Manila 1st District Engineering Office           215
# Bulacan 2nd District Engineering Office                185
# North Manila District Engineering Office               170
# Cebu 7th District Engineering Office                   170
#                                                       ...
# Zamboanga del Norte 4th District Engineering Office      4
# Bataan 3rd District Engineering Office                   3
# Sulu 2nd District Engineering Office                     2
# Siquijor District Engineering Office                     1
# Sulu 1st District Engineering Office                     1
# Name: count, Length: 199, dtype: int64

# %%
# Extended descriptive statistics for key numeric features
num_cols_core = ['ApprovedBudgetForContract', 'ContractCost', 'BudgetDifference', 'DurationDays']
desc_ext = df[num_cols_core].describe(percentiles=[0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99])
print("Extended descriptive statistics:\n", desc_ext)

# Skewness and kurtosis (distribution shape)
sk_vals = {c: stats.skew(df[c].dropna(), bias=False) for c in num_cols_core}
kt_vals = {c: stats.kurtosis(df[c].dropna(), bias=False) for c in num_cols_core}
shape_df = pd.DataFrame({'skew': sk_vals, 'kurtosis': kt_vals})
print("\nDistribution shape (skew, kurtosis):\n", shape_df)

# Outlier detection using IQR for ContractCost and BudgetDifference
def iqr_bounds(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    return lower, upper

lower_cc, upper_cc = iqr_bounds(df['ContractCost'].dropna())
lower_bd, upper_bd = iqr_bounds(df['BudgetDifference'].dropna())

outliers_cc = df[(df['ContractCost'] < lower_cc) | (df['ContractCost'] > upper_cc)][['ProjectId','Region','ApprovedBudgetForContract','ContractCost']]
outliers_bd = df[(df['BudgetDifference'] < lower_bd) | (df['BudgetDifference'] > upper_bd)][['ProjectId','Region','ApprovedBudgetForContract','ContractCost','BudgetDifference']]

print(f"\nContractCost outliers (IQR method): {len(outliers_cc)}")
outliers_cc.head(10)
print(f"\nBudgetDifference outliers (IQR method): {len(outliers_bd)}")
outliers_bd.head(10)

# Keep original yearly summary stats as well
print("\nYearly totals summary (df2.describe()):")
df2.describe()
# Out:
# Extended descriptive statistics:
#         ApprovedBudgetForContract   ContractCost  BudgetDifference  \
# count                   9,043.00       9,043.00          9,043.00
# mean               57,071,746.32  56,303,382.54        768,363.78
# std                40,018,427.41  39,652,211.09      5,405,070.37
# min                 1,158,000.00   1,154,359.00     -3,747,500.75
# 1%                  4,899,512.88   4,742,006.46       -436,351.84
# 5%                  4,950,000.00   4,947,227.82           -177.37
# 25%                28,949,999.64  27,380,790.05              0.00
# 50%                49,000,000.00  48,997,205.76          2,133.57
# 75%                86,850,000.00  86,844,690.24        153,629.08
# 95%               115,800,000.00 114,005,776.38      2,437,182.84
# 99%               193,000,000.00 192,999,466.85     14,699,811.94
# max               310,576,313.24 289,500,000.00    236,438,892.45
#
#        DurationDays
# count      9,043.00
# mean         238.51
# std          116.05
# min           19.00
# 1%            48.00
# 5%            84.00
# 25%          159.00
# 50%          224.00
# 75%          294.00
# 95%          457.00
# 99%          628.00
# max        1,084.00
#
# Distribution shape (skew, kurtosis):
#                             skew  kurtosis
# ApprovedBudgetForContract  1.36      4.02
# ContractCost               1.34      3.89
# BudgetDifference          21.24    666.92
# DurationDays               1.30      3.33
#
# ContractCost outliers (IQR method): 128
#
# BudgetDifference outliers (IQR method): 1890
#
# Yearly totals summary (df2.describe()):
#        TotalApprovedBudget  TotalContractCost       Difference  \
# count                 3.00               3.00             3.00
# mean    172,033,267,324.23 169,717,162,784.21 2,316,104,540.01
# std      30,073,144,829.52  29,317,818,302.73 1,315,188,723.87
# min     145,325,173,051.52 144,481,371,378.01   843,801,673.51
# 25%     155,746,322,903.39 153,637,076,384.51 1,786,811,127.89
# 50%     166,167,472,755.26 162,792,781,391.01 2,729,820,582.28
# 75%     185,387,314,460.58 182,335,058,487.32 3,052,255,973.26
# max     204,607,156,165.90 201,877,335,583.62 3,374,691,364.25
#
#        PercentageSaved
# count             3.00
# mean              1.32
# std               0.73
# min               0.58
# 25%               0.96
# 50%               1.33
# 75%               1.68
# max               2.03

# %%
df
# Out:
#      MainIsland                            Region           Province  \
# 7         Luzon  Cordillera Administrative Region             Apayao
# 8         Luzon  Cordillera Administrative Region             Apayao
# 9         Luzon  Cordillera Administrative Region             Apayao
# 10        Luzon  Cordillera Administrative Region             Apayao
# 11        Luzon  Cordillera Administrative Region             Apayao
# ...         ...                               ...                ...
# 9850   Mindanao                       Region XIII  Surigao del Norte
# 9851   Mindanao                       Region XIII  Surigao del Norte
# 9852   Mindanao                       Region XIII  Surigao del Norte
# 9853   Mindanao                       Region XIII  Surigao del Norte
# 9854   Mindanao                       Region XIII  Surigao del Norte
#
#                                  LegislativeDistrict  \
# 7                      APAYAO (LEGISLATIVE DISTRICT)
# 8                      APAYAO (LEGISLATIVE DISTRICT)
# 9                      APAYAO (LEGISLATIVE DISTRICT)
# 10                     APAYAO (LEGISLATIVE DISTRICT)
# 11                     APAYAO (LEGISLATIVE DISTRICT)
# ...                                              ...
# 9850  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9851  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9852  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9853  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
# 9854  SURIGAO DEL NORTE (FIRST LEGISLATIVE DISTRICT)
#
#                         Municipality  \
# 7                    CONNER (APAYAO)
# 8                    CONNER (APAYAO)
# 9                    CONNER (APAYAO)
# 10                   CONNER (APAYAO)
# 11                   CONNER (APAYAO)
# ...                              ...
# 9850      BURGOS (SURIGAO DEL NORTE)
# 9851  SAN BENITO (SURIGAO DEL NORTE)
# 9852  SAN BENITO (SURIGAO DEL NORTE)
# 9853     SOCORRO (SURIGAO DEL NORTE)
# 9854       PILAR (SURIGAO DEL NORTE)
#
#                               DistrictEngineeringOffice    ProjectId  \
# 7                Apayao 1st District Engineering Office  P00620988LZ
# 8                Apayao 1st District Engineering Office  P00620472LZ
# 9                Apayao 1st District Engineering Office  P00620136LZ
# 10               Apayao 1st District Engineering Office  P00726398LZ
# 11               Apayao 1st District Engineering Office  P00726655LZ
# ...                                                 ...          ...
# 9850  Surigao del Norte 1st District Engineering Office  P00836163MN
# 9851  Surigao del Norte 1st District Engineering Office  P00721401MN
# 9852  Surigao del Norte 1st District Engineering Office  P00836198MN
# 9853  Surigao del Norte 1st District Engineering Office  P00734420MN
# 9854  Surigao del Norte 1st District Engineering Office  P00745952MN
#
#                                             ProjectName  \
# 7     Construction of Barren River (Upstream) Flood ...
# 8     Construction of Barren River (Upstream) Flood ...
# 9     Construction of Barren River (Downstream) Floo...
# 10    Construction of Barren River (Downstream) Floo...
# 11    Construction of Barren River (Downstream) Floo...
# ...                                                 ...
# 9850  Construction of Shore Protection Structure alo...
# 9851  Construction of Flood Control Structure, Nuevo...
# 9852  Construction of Slope Protection Structure alo...
# 9853  Construction of Shore Protection,Brgy. Pamosai...
# 9854  Reconstruction/Rehabilitation of Seawall and R...
#
#                                              TypeOfWork  FundingYear  ...  \
# 7            Construction of Flood Mitigation Structure         2022  ...
# 8            Construction of Flood Mitigation Structure         2022  ...
# 9            Construction of Flood Mitigation Structure         2022  ...
# 10                            Construction of Revetment         2023  ...
# 11                            Construction of Revetment         2023  ...
# ...                                                 ...          ...  ...
# 9850         Construction of Flood Mitigation Structure         2024  ...
# 9851         Construction of Flood Mitigation Structure         2023  ...
# 9852         Construction of Slope Protection Structure         2024  ...
# 9853         Construction of Flood Mitigation Structure         2023  ...
# 9854  Rehabilitation / Major Repair of Flood Control...         2023  ...
#
#                                              Contractor  ContractorCount  \
# 7                  PRIME MASTER CONST. AND DEV'T. CORP.                1
# 8                                BAHRAMLEY CONSTRUCTION                1
# 9                  ASC CONSTRUCTION & CONCRETE PRODUCTS               20
# 10                 ASC CONSTRUCTION & CONCRETE PRODUCTS               20
# 11                     GKA ENGINEERING AND CONSTRUCTION                1
# ...                                                 ...              ...
# 9850  RCDG CONSTRUCTION CORPORATION / LPO1 GROUP OF ...                2
# 9851                            DQT BUILDERS AND SUPPLY                1
# 9852                        BOOMETRIX DEVELOPMENT CORP.                8
# 9853           ROAD EDGE TRADING & DEVELOPMENT SERVICES               50
# 9854  DQT BUILDERS AND SUPPLY / ARN BUILDERS, INC. (...                1
#
#       StartDate ProjectLatitude ProjectLongitude  ProvincialCapital  \
# 7    2022-02-09           17.82           121.27            Kabugao
# 8    2022-03-01           17.82           121.27            Kabugao
# 9    2022-04-04           17.82           121.27            Kabugao
# 10   2023-02-12           17.82           121.27            Kabugao
# 11   2023-02-12           17.80           121.28            Kabugao
# ...         ...             ...              ...                ...
# 9850 2024-05-13           10.02           126.07       Surigao City
# 9851 2023-05-03            9.94           126.04       Surigao City
# 9852 2024-04-05            9.97           126.01       Surigao City
# 9853 2023-07-13            9.65           125.92       Surigao City
# 9854 2023-11-28            9.65           125.91       Surigao City
#
#      ProvincialCapitalLatitude  ProvincialCapitalLongitude  DurationDays  \
# 7                        18.02                      121.17           266
# 8                        18.02                      121.17           296
# 9                        18.02                      121.17           421
# 10                       18.02                      121.17           305
# 11                       18.02                      121.17           130
# ...                        ...                         ...           ...
# 9850                      9.78                      125.49           223
# 9851                      9.78                      125.49           197
# 9852                      9.78                      125.49           287
# 9853                      9.78                      125.49           276
# 9854                      9.78                      125.49           173
#
#      BudgetDifference
# 7          591,507.17
# 8           -1,075.32
# 9             -692.34
# 10               0.00
# 11               0.00
# ...               ...
# 9850            33.32
# 9851         4,976.81
# 9852       100,276.83
# 9853       100,097.50
# 9854       931,645.77
#
# [9043 rows x 24 columns]

# %% [markdown]
# # Visual Representation

# %%
# Correlation and pairwise relationships for key numeric variables
corr_cols = ['ApprovedBudgetForContract', 'ContractCost', 'BudgetDifference', 'DurationDays', 'ContractorCount']

# Pairwise relationships (robust sampling after dropping NA)
available = df[corr_cols].dropna()
sample_size = min(300, len(available))
if sample_size > 0:
    sns.pairplot(available.sample(sample_size, random_state=42), corner=True, diag_kind='kde')
    plt.suptitle('Pairwise Relationships', y=1.02)
    plt.show()
else:
    print('Not enough complete rows for pairplot after dropping NA.')

# %%
# Region distribution (pie chart)
region_counts = df['Region'].value_counts()

# Pie chart
plt.figure(figsize=(10,8))
plt.pie(region_counts,
        labels=region_counts.index,
        autopct='%1.1f%%',  # show percentage
        startangle=140,      # rotate start for better visualization
        colors=plt.cm.tab20.colors)  # use a colormap for colors

plt.title('Distribution of Projects by Region')
plt.axis('equal')  # make pie chart circular
plt.show()

# %%
# Main Island distribution (pie chart)
island_groups = df['MainIsland'].value_counts()
plt.figure(figsize=(10,8))
plt.pie(island_groups,
        labels=island_groups.index, # rotate start for better visualization
        autopct='%1.1f%%',
        colors=plt.cm.tab20.colors)  # use a colormap for colors

plt.title('Distribution of Projects by Main Island')
plt.axis('equal')  # make pie chart circular
plt.show()

# %%
# Type of Work distribution (pie chart)
tow = df['TypeOfWork'].value_counts()
small_tow = tow[tow / tow.sum() >= 0.01].copy()
others_sum = tow[tow / tow.sum() < 0.01].sum()
if others_sum > 0:
    small_tow.loc['Others'] = others_sum
plt.figure(figsize=(10, 8))
plt.pie(small_tow,
        labels=small_tow.index,
        autopct='%1.1f%%',
        colors=plt.cm.tab20.colors)

plt.title('Distribution of Projects by Type of Work')
plt.axis('equal')
plt.show()

# %%
# Distributions with KDE
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df['ApprovedBudgetForContract'].dropna(), bins=30, kde=True, color='skyblue')
plt.title('Approved Budget Distribution')
plt.xlabel('Approved Budget (PHP)'); plt.ylabel('Project Count')
plt.gca().xaxis.set_major_formatter(FuncFormatter(php_fmt))

plt.subplot(1,2,2)
sns.histplot(df['ContractCost'].dropna(), bins=30, kde=True, color='salmon')
plt.title('Contract Cost Distribution')
plt.xlabel('Contract Cost (PHP)'); plt.ylabel('Project Count')
plt.gca().xaxis.set_major_formatter(FuncFormatter(php_fmt))
plt.tight_layout()
plt.show()

# %%
# Contract cost by Main Island boxplot
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='MainIsland', y='ContractCost')
plt.title('Contract Cost by Main Island')
plt.xlabel('Main Island'); plt.ylabel('Contract Cost (PHP)')
plt.gca().yaxis.set_major_formatter(FuncFormatter(php_fmt))
plt.tight_layout()
plt.show()

# %%
# Projects per Funding Year
plt.figure(figsize=(10,6))
df['FundingYear'].value_counts().sort_index().plot(kind='bar', color='steelblue')
plt.title('Projects per Funding Year')
plt.xlabel('Funding Year'); plt.ylabel('Number of Projects')
plt.tight_layout()
plt.show()

# %%
# Total Approved Budget vs Contract Cost by year line chart
plt.figure(figsize=(10,6))
year_totals = df.groupby('FundingYear')[['ApprovedBudgetForContract','ContractCost']].sum().sort_index()
plt.plot(year_totals.index, year_totals['ApprovedBudgetForContract'], marker='o', label='Total Approved Budget')
plt.plot(year_totals.index, year_totals['ContractCost'], marker='o', label='Total Contract Cost')
plt.legend(); plt.title('Totals by Funding Year'); plt.xlabel('Year'); plt.ylabel('Total Amount (PHP)')
plt.gca().yaxis.set_major_formatter(FuncFormatter(php_fmt))
plt.tight_layout()
plt.show()

# %%
# Budget vs Cost with regression line and y=x reference
plt.figure(figsize=(8,6))
sns.regplot(data=df, x='ApprovedBudgetForContract', y='ContractCost', scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
maxv = max(df['ApprovedBudgetForContract'].max(), df['ContractCost'].max())
plt.plot([0, maxv], [0, maxv], '--', color='gray', label='y = x')
plt.legend(); plt.title('Approved Budget vs. Contract Cost')
plt.xlabel('Approved Budget (PHP)'); plt.ylabel('Contract Cost (PHP)')
ax = plt.gca(); ax.xaxis.set_major_formatter(FuncFormatter(php_fmt)); ax.yaxis.set_major_formatter(FuncFormatter(php_fmt))
plt.tight_layout()
plt.show()

# %%
# Interactive map (Mapbox): projects colored by Type of Work
latitude = df['ProjectLatitude']
longitude = df['ProjectLongitude']
conCost = df['ContractCost'].fillna(0)

fig1 = px.scatter_map(df, lat=latitude, lon=longitude, hover_name='ProjectName',
                     map_style='satellite-streets', color='TypeOfWork',
                     height=800, width=1000,
                     color_discrete_sequence=px.colors.qualitative.Bold)
fig1.update_layout(
    title='Flood Control Projects in the Philippines by Type of Work',
    title_x=0.5,
    title_font_size=24,
    title_font_family='Courier New, monospace',
    title_font_color='red',
    title_xanchor='center',
    title_yanchor='top',
    legend_title_text='Type of Work'
)
fig1.show()

# %%
# Interactive map (Mapbox): projects colored by Contract Cost
fig = px.scatter_map(df, lat=latitude, lon=longitude, hover_name='ProjectName',
                     map_style='satellite-streets', color=conCost,
                     height=800, width=1000,
                     labels={'color': 'Contract Cost (PHP)'})
fig.update_coloraxes(colorbar_title_text='Contract Cost (PHP)', colorbar_tickprefix='₱', colorbar_tickformat='~s')
fig.show()

# %%
# Top Contractors by Total Contract Cost (bar chart)
# Compute total Contract Cost per contractor and plot top 15
top_n = 15
contractor_cost = (df.groupby('Contractor')['ContractCost']
                     .sum()
                     .sort_values(ascending=False)
                     .head(top_n))
plt.figure(figsize=(12,8))
sns.barplot(x=contractor_cost.values, y=contractor_cost.index, orient='h')
plt.title(f'Top {top_n} Contractors by Total Contract Cost')
plt.xlabel('Total Contract Cost (PHP)'); plt.ylabel('Contractor')
plt.gca().xaxis.set_major_formatter(FuncFormatter(php_fmt))
plt.tight_layout()
plt.show()

# %%
import folium as fm
import streamlit_folium as st_folium

CENTER = (11.8917830337768213,122.41992187500001)
m = fm.Map(
    location=CENTER,
    zoom_start=6,
    tiles="Esri.WorldImagery",
    control_scale=True,
    prefer_canvas=True
)
fm.plugins.Fullscreen(
    position="topright",
    title="Expand me",
    title_cancel="Exit me",
    force_separate_button=True,
).add_to(m)
fm.TileLayer("Cartodb dark_matter", name="Dark").add_to(m)
fm.TileLayer("OpenStreetMap", name="Street").add_to(m)
fm.LayerControl().add_to(m)
m
st_folium(m, height=500, returned_objects=[], width=1000)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d761045b988ce539d5ce43b220363f13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d761045b988ce539d5ce43b220363f13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d761045b988ce539d5ce43b220363f13 = L.map(
#                 &quot;map_d761045b988ce539d5ce43b220363f13&quot;,
#                 {
#                     center: [11.891783033776822, 122.41992187500001],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d761045b988ce539d5ce43b220363f13);
#
#
#
#
#
#             var tile_layer_a09956c1c8b31cb703bd2cc8754d3385 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a09956c1c8b31cb703bd2cc8754d3385.addTo(map_d761045b988ce539d5ce43b220363f13);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;title&quot;: &quot;Expand me&quot;,
#   &quot;titleCancel&quot;: &quot;Exit me&quot;,
#   &quot;forceSeparateButton&quot;: true,
# }
#             ).addTo(map_d761045b988ce539d5ce43b220363f13);
#
#
#             var tile_layer_bf3ef5e48275b32eb163bd54292144e4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf3ef5e48275b32eb163bd54292144e4.addTo(map_d761045b988ce539d5ce43b220363f13);
#
#
#             var tile_layer_beede99bbe474c9117131fbceffe5bff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_beede99bbe474c9117131fbceffe5bff.addTo(map_d761045b988ce539d5ce43b220363f13);
#
#
#             var layer_control_e42e95f3e873b60f37bb882dfa2df627_layers = {
#                 base_layers : {
#                     &quot;esriworldimagery&quot; : tile_layer_a09956c1c8b31cb703bd2cc8754d3385,
#                     &quot;Dark&quot; : tile_layer_bf3ef5e48275b32eb163bd54292144e4,
#                     &quot;Street&quot; : tile_layer_beede99bbe474c9117131fbceffe5bff,
#                 },
#                 overlays :  {
#                 },
#             };
#             let layer_control_e42e95f3e873b60f37bb882dfa2df627 = L.control.layers(
#                 layer_control_e42e95f3e873b60f37bb882dfa2df627_layers.base_layers,
#                 layer_control_e42e95f3e873b60f37bb882dfa2df627_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_d761045b988ce539d5ce43b220363f13);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
